# %%
# %load_ext autoreload
# %autoreload 2
from ensemble_manager import EnsembleManager
from json_handler import JsonHandler
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
identifier = '20250511_155500'
json_handler = JsonHandler() #dont pass dir here
ensemble_manager = EnsembleManager(run_identifier=identifier, json_handler=json_handler)
print(ensemble_manager.ensemble_dir)
# Out:
# ./Menagerie/ensemble_20250511_155500

# %%
loaded_models = ensemble_manager.load_ensemble_data()
# Out:
# {'run_identifier': '20250511_155500', 'num_ensembles': 20, 'num_datsets': 3, 'description': '', 'manifest': []}

# %%
loaded_models[0]
# Out:
# {'model': FCN3Network(
#    (fc1): Linear(in_features=10, out_features=50, bias=True)
#    (fc2): Linear(in_features=50, out_features=50, bias=True)
#    (fc3): Linear(in_features=50, out_features=1, bias=True)
#  ),
#  'data': tensor([[-0.8447,  1.3540,  0.8981,  ...,  0.8751, -1.2604, -1.9088],
#          [ 0.7303,  2.9956,  0.3391,  ...,  0.2418,  1.8662,  1.1292],
#          [ 2.0787,  2.1649, -0.4295,  ...,  0.9379, -0.4727, -0.7855],
#          ...,
#          [-1.1306, -1.3165,  0.5240,  ..., -2.1827,  0.1706,  0.4214],
#          [-1.3989, -1.9095,  0.7081,  ..., -0.3726, -0.0728, -0.0300],
#          [-0.3444, -1.6574,  0.5165,  ..., -0.3404,  1.2578, -0.8191]],
#         device='mps:0'),
#  'target': tensor([[ 1.1618e+00],
#          [-4.2497e+00],
#          [-4.8310e+00],
#          [-5.9145e+00],
#          [ 9.6831e-01],
#          [ 8.5938e+00],
#          [ 3.9429e+00],
#          [ 1.6598e+00],
#          [-2.6865e+00],
#          [-3.7496e+00],
# ...
